# %% [markdown]
# <a href="https://colab.research.google.com/github/imaadfakier/google-play-store-app-analytics/blob/main/Google_Play_Store_App_Analytics_(start).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.head()
# Out:
#                                             App  ...         Android_Ver
# 0                       Ak Parti Yardım Toplama  ...          4.1 and up
# 1                    Ain Arabic Kids Alif Ba ta  ...          3.0 and up
# 2  Popsicle Launcher for Android P 9.0 launcher  ...          4.2 and up
# 3                     Command & Conquer: Rivals  ...  Varies with device
# 4                                    CX Network  ...          4.1 and up
#
# [5 rows x 12 columns]

# %%
df_apps.tail()
# Out:
#                   App Category  Rating  ...  Genres   Last_Updated Android_Ver
# 10836  Subway Surfers     GAME    4.50  ...  Arcade  July 12, 2018  4.1 and up
# 10837  Subway Surfers     GAME    4.50  ...  Arcade  July 12, 2018  4.1 and up
# 10838  Subway Surfers     GAME    4.50  ...  Arcade  July 12, 2018  4.1 and up
# 10839  Subway Surfers     GAME    4.50  ...  Arcade  July 12, 2018  4.1 and up
# 10840  Subway Surfers     GAME    4.50  ...  Arcade  July 12, 2018  4.1 and up
#
# [5 rows x 12 columns]

# %%
df_apps.sample(n=5)
# Out:
#                                                App  ...         Android_Ver
# 10303  APUS Launcher - Theme, Wallpaper, Hide Apps  ...        4.0.3 and up
# 2491                           Media Sosial TNI AU  ...          2.1 and up
# 1813                       Diabetes & Diet Tracker  ...          5.0 and up
# 5418                                  Nero AirBurn  ...          4.0 and up
# 6908                  My CookBook (Recipe Manager)  ...  Varies with device
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
# df_apps.drop([['Last_Updated', 'Android_Ver']], axis=1)  # wrong!
df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1)
# df_apps = df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1)
df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1, inplace=True)

# %%
df_apps.sample(10)
# Out:
#                                                      App  ...                   Genres
# 2017               Ag PhD Planting Population Calculator  ...        Books & Reference
# 2360                                   AE Fishing Hunter  ...                Adventure
# 6344                                My Chakra Meditation  ...         Health & Fitness
# 10249           InstaSize Photo Filters & Collage Editor  ...              Photography
# 2093                                  CK Employee Portal  ...                 Business
# 10606                                       Fruit Ninja®  ...                   Arcade
# 3510                                  tTorrent - ad free  ...  Video Players & Editors
# 3202                                          FX LITE BO  ...                  Finance
# 10482                                Google Korean Input  ...                    Tools
# 10147  Photo Lab Picture Editor: face effects, art fr...  ...              Photography
#
# ...

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
# How may rows have a NaN value (not-a-number) in the Ratings column?
df_apps['Rating'].isna().values.sum()

# nan_rows = df_apps[df_apps.Rating.isna()]
# print(nan_rows.shape)
# nan_rows.head()
# Out:
# 1474

# %%
# df_apps_clean = df_apps[df_apps['Rating'].notna()]
# df_apps_clean
# # df_apps_clean['Rating'].isna().values.any()
# ---
print(df_apps.isna().any())
# df_apps_clean = df_apps[df_apps[['Rating', 'Type']].notna()]  # unfortunately not possible
df_apps_clean = df_apps.dropna()
# df_apps.dropna(inplace=True)
df_apps_clean
# df_apps[df_apps[['Rating']].notna()]
# df_apps[df_apps['Type'].notna()]
print(df_apps_clean.shape)
# Out:
# App               False
# Category          False
# Rating             True
# Reviews           False
# Size_MBs          False
# Installs          False
# Type               True
# Price             False
# Content_Rating    False
# Genres            False
# dtype: bool
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
# Are there any duplicates in data?
# df_apps_clean.duplicated()
# # df_apps_clean.duplicated().any()  # doesn't output desired result format
print(df_apps_clean.duplicated().any())
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]  # simple conditional filtering
print(duplicated_rows.shape)
# duplicated_rows.head()
duplicated_rows[:50:]
# Out:
# True
# (476, 10)
#                                                     App  ...                        Genres
# 946                              420 BZ Budeze Delivery  ...                       Medical
# 1133                                        MouseMingle  ...                        Dating
# 1196         Cardiac diagnosis (heart rate, arrhythmia)  ...                       Medical
# 1231                                       Sway Medical  ...                       Medical
# 1247                     Chat Kids - Chat Room For Kids  ...                        Dating
# 1379                    CT Scan Cross Sectional Anatomy  ...                       Medical
# 1616                          JH Blood Pressure Monitor  ...                       Medical
# 1642             Cardi B Live Stream Video Chat - Prank  ...                        Dating
# 1813                            Diabetes & Diet Tracker  ...                       Medical
# ...

# %%
df_apps_clean[df_apps_clean['App'] == 'Instagram'].duplicated().count()
# df_apps_clean[df_apps_clean['App'] == 'Instagram'].duplicated().sum()
# Out:
# 4

# %%
# df_apps_clean.drop_duplicates(inplace=True)
df_apps_clean = df_apps_clean.drop_duplicates()  # too strict by default
print(df_apps_clean[df_apps_clean['App'] == 'Instagram'].duplicated().count())
df_apps_clean[df_apps_clean['App'] == 'Instagram']
# Out:
# 3
#              App Category  Rating   Reviews  ...  Type Price Content_Rating  Genres
# 10806  Instagram   SOCIAL    4.50  66577313  ...  Free     0           Teen  Social
# 10808  Instagram   SOCIAL    4.50  66577446  ...  Free     0           Teen  Social
# 10810  Instagram   SOCIAL    4.50  66509917  ...  Free     0           Teen  Social
#
# [3 rows x 10 columns]

# %%
# need to specify the subset for identifying duplicates
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Price'])
print(df_apps_clean[df_apps_clean['App'] == 'Instagram'].duplicated().count())
df_apps_clean[df_apps_clean['App'] == 'Instagram']
# Out:
# 1
#              App Category  Rating   Reviews  ...  Type Price Content_Rating  Genres
# 10806  Instagram   SOCIAL    4.50  66577313  ...  Free     0           Teen  Social
#
# [1 rows x 10 columns]

# %%
df_apps_clean.head()
# Out:
#                                                 App  ...   Genres
# 21                              KBA-EZ Health Guide  ...  Medical
# 28                                         Ra Ga Ba  ...   Arcade
# 47                                          Mu.F.O.  ...   Arcade
# 82                                 Brick Breaker BR  ...   Arcade
# 99  Anatomy & Physiology Vocabulary Exam Review App  ...  Medical
#
# [5 rows x 10 columns]

# %%
df_apps_clean.tail()
# Out:
#                            App  ...                   Genres
# 10824             Google Drive  ...             Productivity
# 10828                  YouTube  ...  Video Players & Editors
# 10829  Google Play Movies & TV  ...  Video Players & Editors
# 10831              Google News  ...         News & Magazines
# 10835           Subway Surfers  ...                   Arcade
#
# [5 rows x 10 columns]

# %%
df_apps_clean.shape
# Out:
# (8199, 10)

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.sort_values('Rating', ascending=False).head()
# Out:
#                       App     Category  ...  Content_Rating       Genres
# 21    KBA-EZ Health Guide      MEDICAL  ...        Everyone      Medical
# 1230         Sway Medical      MEDICAL  ...        Everyone      Medical
# 1227    AJ Men's Grooming    LIFESTYLE  ...        Everyone    Lifestyle
# 1224       FK Dedinje BGD       SPORTS  ...        Everyone       Sports
# 1223      CB VIDEO VISION  PHOTOGRAPHY  ...        Everyone  Photography
#
# [5 rows x 10 columns]

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values('Size_MBs', ascending=False).head()
# Out:
#                                   App  ...                  Genres
# 9942   Talking Babsy Baby: Baby Games  ...  Lifestyle;Pretend Play
# 10687          Hungry Shark Evolution  ...                  Arcade
# 9943            Miami crime simulator  ...                  Action
# 9944     Gangster Town: Vice District  ...              Simulation
# 3144                       Vi Trainer  ...        Health & Fitness
#
# [5 rows x 10 columns]

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values('Reviews', ascending=False).head()
# Out:
#                                             App  ...         Genres
# 10805                                  Facebook  ...         Social
# 10785                        WhatsApp Messenger  ...  Communication
# 10806                                 Instagram  ...         Social
# 10784  Messenger – Text and Video Chat for Free  ...  Communication
# 10650                            Clash of Clans  ...       Strategy
#
# [5 rows x 10 columns]

# %%
# Are there any paid apps among the top 50?
top_50_apps_reviews_df = df_apps_clean.sort_values('Reviews', ascending=False)[:50:]
# top_50_apps_reviews_df = df_apps_clean.sort_values('Reviews', ascending=False).head(50)
# # top_50_apps_reviews_df
# top_50_apps_reviews_df[top_50_apps_reviews_df['Type'] == 'Paid']
top_50_apps_reviews_df[top_50_apps_reviews_df['Type'] == 'Paid']['Type'].values.any()
# Out:
# False

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean.Content_Rating.value_counts()
ratings
# Out:
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content_Rating, dtype: int64

# %%
# creating graph object
fig = px.pie(labels=ratings.index, values=ratings.values)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0a21a5dd-77ce-4ef8-8fdc-5612d338470d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0a21a5dd-77ce-4ef8-8fdc-5612d338470d")) {
#                     Plotly.newPlot(
#                         '0a21a5dd-77ce-4ef8-8fdc-5612d338470d',
# ...

# %%
# If you’d like to configure other aspects of the chart, that you can’t see in 
# the list of parameters, you can call a method called .update_traces(). In 
# plotly lingo, “traces” refer to graphical marks on a figure. Think of “traces” 
# as collections of attributes. Here we update the traces to change how the text 
# is displayed.
fig = px.pie(
    labels=ratings.index, 
    values=ratings.values, 
    title="Content Rating", 
    names=ratings.index,
)
fig.update_traces(textposition='outside', textinfo='percent+label') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dd4a3f38-7afb-4885-b5ea-b011c231cff2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dd4a3f38-7afb-4885-b5ea-b011c231cff2")) {
#                     Plotly.newPlot(
#                         'dd4a3f38-7afb-4885-b5ea-b011c231cff2',
# ...

# %%
fig = px.pie(
    labels=ratings.index, 
    values=ratings.values, 
    title="Content Rating", 
    names=ratings.index, 
    hole=0.6,
)
fig.update_traces(textposition='inside', textfont_size=15, textinfo='percent') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f32db2d5-43d2-429c-964e-9a24f4a66afa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f32db2d5-43d2-429c-964e-9a24f4a66afa")) {
#                     Plotly.newPlot(
#                         'f32db2d5-43d2-429c-964e-9a24f4a66afa',
# ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column. [DONE]
#
# Count the number of apps at each level of installations. [DONE]
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
# To check the data types you can either use .describe() on the column or 
# .info() on the DataFrame.
print(df_apps_clean.Installs.describe())
print('\n')
print(df_apps_clean.info())

# Both of these show that we are dealing with a non-numeric data type. In this 
# case, the type is "object".
# Out:
# count          8199
# unique           19
# top       1,000,000
# freq           1417
# Name: Installs, dtype: object
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   object
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 704.6+ KB
# None

# %%
df_apps_clean.sample(5)
# Out:
#                                                  App  ...         Genres
# 10593                                 Talking Angela  ...  Entertainment
# 3581                                       Brit + Co  ...      Lifestyle
# 1641          Cardi B Live Stream Video Chat - Prank  ...         Dating
# 8164   IndiaMART: Search Products, Buy, Sell & Trade  ...       Business
# 7139                  TorrDroid - Torrent Downloader  ...          Tools
#
# [5 rows x 10 columns]

# %%
# df_apps_clean[df_apps_clean['Installs'] > '1,000,000,000']  # question incorrectly interpreted

# %%
df_apps_clean['Installs']
type(df_apps_clean['Installs'][21])
# print(type(df_apps_clean['Installs'][21]))
# Out:
# str

# %%
df_apps_clean['Installs'].value_counts()

# # or ...

# # If we take two of the columns, say Installs and the App name, we can count the 
# # number of entries per level of installations with .groupby() and .count(). 
# # However, because we are dealing with a non-numeric data type, the ordering is 
# # not helpful. The reason Python is not recognising our installs as numbers is 
# # because of the comma (,) characters.
# df_apps_clean[['App', 'Installs']].groupby('Installs').count
# Out:
# 1,000,000        1417
# 100,000          1096
# 10,000            988
# 10,000,000        933
# 1,000             698
# 5,000,000         607
# 500,000           504
# 50,000            457
# 5,000             425
# 100               303
# 50,000,000        202
# 500               199
# 100,000,000       189
# 10                 69
# 50                 56
# 500,000,000        24
# 1,000,000,000      20
# 5                   9
# 1                   3
# Name: Installs, dtype: int64

# %%
df_apps_clean['Installs'].apply(lambda install: int(install.replace(',', '')))
# Out:
# 21                1
# 28                1
# 47                1
# 82                5
# 99                5
#             ...
# 10824    1000000000
# 10828    1000000000
# 10829    1000000000
# 10831    1000000000
# 10835    1000000000
# Name: Installs, Length: 8199, dtype: int64

# %%
# or ...

# We can remove the comma (,) character - or any character for that matter - 
# from a DataFrame using the string’s .replace() method. Here we’re saying: 
# “replace the , with an empty string”. This completely removes all the commas 
# in the Installs column. We can then convert our data to a number using 
# .to_numeric().
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(',', "")
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %%
df_apps_clean['Installs'] = df_apps_clean['Installs'].apply(lambda install: int(install.replace(',', '')))
df_apps_clean.sample(11)
# Out:
#                                                 App  ...            Genres
# 10231                        Geometry Dash Meltdown  ...            Arcade
# 9207     Live Hold’em Pro Poker - Free Casino Games  ...              Card
# 8463   RC Monster Truck - Offroad Driving Simulator  ...            Racing
# 7292                         Soccer Clubs Logo Quiz  ...            Trivia
# 2724                            McClatchy DC Bureau  ...  News & Magazines
# 6794                       A Call From Santa Claus!  ...     Entertainment
# 9923                                   Rope'n'Fly 4  ...            Action
# 958            Food-Aw - Order Food Online in Aruba  ...      Food & Drink
# 5904   Frigo Magic: Easy recipe idea and anti-waste  ...      Food & Drink
# 855                       Cy-Fair VFD EMS Protocols  ...           Medical
# 9504                 Train Racing Games 3D 2 Player  ...            Racing
#
# [11 rows x 10 columns]

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.sample(7)
# # ---
# # If you look at the data type of the price column:
# df_apps_clean.Price.describe()
# Out:
#                                           App  ...            Genres
# 10313  File Commander - File Manager/Explorer  ...          Business
# 9136                           Nike+ Run Club  ...  Health & Fitness
# 4680         Anime et Manga Amino en Français  ...            Social
# 5596                           All C Programs  ...         Education
# 5125                               Novinky.cz  ...  News & Magazines
# 4372                                  eBiblio  ...  Libraries & Demo
# 3324                                 The List  ...  News & Magazines
#
# [7 rows x 10 columns]

# %%
df_apps_clean['Price'].apply(lambda price: float(price.replace('$', '')))
# df_apps_clean['Price'] = df_apps_clean['Price'].apply(lambda price: int(price.replace('$', '')))
df_apps_clean.Price = df_apps_clean.Price.astype(str).str.replace('$', "")
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)
df_apps_clean['Price']
# Out:
# 21      0.00
# 28      1.49
# 47      0.99
# 82      0.00
# 99      0.00
#         ...
# 10824   0.00
# 10828   0.00
# 10829   0.00
# 10831   0.00
# 10835   0.00
# Name: Price, Length: 8199, dtype: float64

# %%
# df_apps_clean.sort_values('Price', ascending=False)[:20:]
df_apps_clean.sort_values('Price', ascending=False).head(20)
# Out:
#                                  App   Category  ...  Content_Rating         Genres
# 3946        I'm Rich - Trump Edition  LIFESTYLE  ...        Everyone      Lifestyle
# 2461              I AM RICH PRO PLUS    FINANCE  ...        Everyone        Finance
# 4606               I Am Rich Premium    FINANCE  ...        Everyone        Finance
# 3145              I am rich(premium)    FINANCE  ...        Everyone        Finance
# 3554                      💎 I'm rich  LIFESTYLE  ...        Everyone      Lifestyle
# 5765                       I am rich  LIFESTYLE  ...        Everyone      Lifestyle
# 1946  I am rich (Most expensive app)    FINANCE  ...            Teen        Finance
# 2775                   I Am Rich Pro     FAMILY  ...        Everyone  Entertainment
# 3221                  I am Rich Plus     FAMILY  ...        Everyone  Entertainment
# 3114                       I am Rich    FINANCE  ...        Everyone        Finance
# ...

# %% [markdown]
# ### The most expensive apps sub $250

# %%
# # df_apps_clean.drop(df_apps_clean[df_apps_clean['Price'] > 250])
df_apps_clean.drop(df_apps_clean[df_apps_clean['Price'] > 250].index, inplace=True)
# # df_apps_clean = df_apps_clean.drop(df_apps_clean[df_apps_clean['Price'] > 250])
df_apps_clean.sort_values('Price', ascending=False).head(5)
# Out:
#                             App   Category  ...     Genres  Revenue_Estimate
# 2281  Vargo Anesthesia Mega App    MEDICAL  ...    Medical         79,990.00
# 1407               LTC AS Legal    MEDICAL  ...    Medical          3,999.00
# 2629           I am Rich Person  LIFESTYLE  ...  Lifestyle         37,990.00
# 2481    A Manual of Acupuncture    MEDICAL  ...    Medical         33,990.00
# 2463         PTA Content Master    MEDICAL  ...    Medical         29,990.00
#
# [5 rows x 11 columns]

# %%
df_apps_clean['Revenue_Estimate'] = df_apps_clean.Installs.mul(df_apps_clean.Price)
df_apps_clean['Revenue_Estimate'] = df_apps_clean.Price * df_apps_clean.Installs

# %%
df_apps_clean.head()
# Out:
#                                                 App  ... Revenue_Estimate
# 21                              KBA-EZ Health Guide  ...             0.00
# 28                                         Ra Ga Ba  ...             1.49
# 47                                          Mu.F.O.  ...             0.99
# 82                                 Brick Breaker BR  ...             0.00
# 99  Anatomy & Physiology Vocabulary Exam Review App  ...             0.00
#
# [5 rows x 11 columns]

# %%
df_apps_clean.tail()
# Out:
#                            App  ... Revenue_Estimate
# 10824             Google Drive  ...             0.00
# 10828                  YouTube  ...             0.00
# 10829  Google Play Movies & TV  ...             0.00
# 10831              Google News  ...             0.00
# 10835           Subway Surfers  ...             0.00
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean.sort_values('Revenue_Estimate', ascending=False)[:10:]
# df_apps_clean.sort_values('Revenue_Estimate', ascending=False).head(10)
# Out:
#                                 App  ... Revenue_Estimate
# 9220                      Minecraft  ...    69,900,000.00
# 8825                  Hitman Sniper  ...     9,900,000.00
# 7151  Grand Theft Auto: San Andreas  ...     6,990,000.00
# 7477            Facetune - For Free  ...     5,990,000.00
# 7977        Sleep as Android Unlock  ...     5,990,000.00
# 6594            DraStic DS Emulator  ...     4,990,000.00
# 6082                   Weather Live  ...     2,995,000.00
# 7954                    Bloons TD 5  ...     2,990,000.00
# 7633        Five Nights at Freddy's  ...     2,990,000.00
# 6746     Card Wars - Adventure Time  ...     2,990,000.00
#
# [10 rows x 11 columns]

# %%
top_10_highest_grossing_apps = df_apps_clean.sort_values('Revenue_Estimate', ascending=False).head(10)
top_10_highest_grossing_apps[top_10_highest_grossing_apps['Category'] == 'GAME']['Category'].count()
# Out:
# 4

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_clean.Category.nunique()

# Which shows us that we there are 33 unique categories.
# Out:
# 33

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
# To calculate the number of apps per category we can use our old friend 
# .value_counts()
top10_category = df_apps_clean.Category.value_counts()[:10]
top10_category
# Out:
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: Category, dtype: int64

# %%
bar = px.bar(x = top10_category.index,  # index = category name
             y = top10_category.values)

bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="34933316-b1f3-46a7-bb97-dd8a328ef258" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("34933316-b1f3-46a7-bb97-dd8a328ef258")) {
#                     Plotly.newPlot(
#                         '34933316-b1f3-46a7-bb97-dd8a328ef258',
# ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
# Based on the number of apps, the Family and Game categories are the most 
# competitive. Releasing yet another app into these categories will make it hard 
# to get noticed.

# But what if we look at it from a different perspective? What matters is not 
# just the total number of apps in the category but how often apps are 
# downloaded in that category. This will give us an idea of how popular a 
# category is. First, we have to group all our apps by category and sum the 
# number of installations:
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)

# %%
# Then we can create a horizontal bar chart, simply by adding the orientation 
# parameter:
h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h')
  
h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="94e5b565-f4a8-4f00-93f0-887312375265" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("94e5b565-f4a8-4f00-93f0-887312375265")) {
#                     Plotly.newPlot(
#                         '94e5b565-f4a8-4f00-93f0-887312375265',
# ...

# %%
# We can also add a custom title and axis labels like so:
h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h',
               title='Category Popularity')
 
h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')

h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="eb1b4827-c959-406d-83eb-e6193390146a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eb1b4827-c959-406d-83eb-e6193390146a")) {
#                     Plotly.newPlot(
#                         'eb1b4827-c959-406d-83eb-e6193390146a',
# ...

# %%
# Now we see that Games and Tools are actually the most popular categories. If 
# we plot the popularity of a category next to the number of apps in that 
# category we can get an idea of how concentrated a category is. Do few apps 
# have most of the downloads or are the downloads spread out over many apps?

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
# First, we need to work out the number of apps in each category (similar to 
# what we did previously).
# df_app_installs_per_category = df_apps_clean[['App', 'Category', 'Installs']].groupby('Category').sum()
# df_app_installs_per_category = df_apps_clean[['App', 'Category', 'Installs']].groupby('Category').count()
df_app_installs_per_category = df_apps_clean[['App', 'Category', 'Installs']].groupby('Category').agg({'App': pd.Series.count, 'Installs': pd.Series.sum})
print('The dimensions of the DataFrame are: {dimensions}'.format(dimensions=df_app_installs_per_category.shape))
print(df_app_installs_per_category)
# ---
cat_number = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})
print(cat_number)
# Out:
# The dimensions of the DataFrame are: (33, 2)
#                       App     Installs
# Category
# ART_AND_DESIGN         61    114233100
# AUTO_AND_VEHICLES      73     53129800
# BEAUTY                 42     26916200
# BOOKS_AND_REFERENCE   169   1665791655
# BUSINESS              262    692018120
# COMICS                 54     44931100
# COMMUNICATION         257  11039241530
# DATING                134    140912410
# EDUCATION             118    352852000
# ENTERTAINMENT         102   2113660000
# EVENTS                 45     15949410
# FAMILY               1606   4437554490
# FINANCE               296    455249400
# FOOD_AND_DRINK         94    211677750
# GAME                  910  13858762717
# HEALTH_AND_FITNESS    243   1134006220
# HOUSE_AND_HOME         62     97082000
# LIBRARIES_AND_DEMO     64     52083000
# LIFESTYLE             297    503611120
# MAPS_AND_NAVIGATION   118    503267560
# MEDICAL               292     39162676
# ...

# %%
# Then we can use .merge() and combine the two DataFrames.
cat_merged_df = pd.merge(cat_number, category_installs, on='Category', how="inner")
print(f'The dimensions of the DataFrame are: {cat_merged_df.shape}')
cat_merged_df.sort_values('Installs', ascending=False)
# Out:
# The dimensions of the DataFrame are: (33, 2)
#                       App     Installs
# Category
# GAME                  910  13858762717
# COMMUNICATION         257  11039241530
# TOOLS                 719   8099724500
# PRODUCTIVITY          301   5788070180
# SOCIAL                203   5487841475
# PHOTOGRAPHY           263   4649143130
# FAMILY               1606   4437554490
# VIDEO_PLAYERS         148   3916897200
# TRAVEL_AND_LOCAL      187   2894859300
# NEWS_AND_MAGAZINES    204   2369110650
# ENTERTAINMENT         102   2113660000
# BOOKS_AND_REFERENCE   169   1665791655
# PERSONALIZATION       298   1532352930
# SHOPPING              180   1400331540
# HEALTH_AND_FITNESS    243   1134006220
# SPORTS                260   1096431465
# BUSINESS              262    692018120
# LIFESTYLE             297    503611120
# MAPS_AND_NAVIGATION   118    503267560
# FINANCE               296    455249400
# WEATHER                72    361096500
# ...

# %%
# Now we can create the chart. Note that we can pass in an entire DataFrame and 
# specify which columns should be used for the x and y by column name.
# fig = px.scatter(
#     x=df_app_installs_per_category.App, 
#     y=df_app_installs_per_category.Installs, 
#     color=df_app_installs_per_category.Installs
# )

# fig.update_layout(yaxis=dict(type='log'))

# fig.show()
scatter = px.scatter(
    # data=cat_merged_df,
    cat_merged_df, # data
    # x='App', # column name
    x=cat_merged_df.App,
    # y='Installs', 
    y=cat_merged_df.Installs, 
    title='Category Concentration', 
    # size='App', 
    size=cat_merged_df.App, 
    hover_name=cat_merged_df.index, 
    # color='Installs'
    color=cat_merged_df.Installs
)
 
scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))
 
scatter.show()

# What we see is that the categories like Family, Tools, and Game have many 
# different apps sharing a high number of downloads. But for the categories like 
# video players and entertainment, all the downloads are concentrated in very 
# few apps.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0d0810ba-5621-4653-a5fa-3ebd93e3ecf6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0d0810ba-5621-4653-a5fa-3ebd93e3ecf6")) {
#                     Plotly.newPlot(
#                         '0d0810ba-5621-4653-a5fa-3ebd93e3ecf6',
# ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_clean['Genres'].nunique()
len(df_apps_clean.Genres.unique())
# Out:
# 114

# %%
df_apps_clean[['App', 'Genres']][:50:]
# Out:
#                                                    App             Genres
# 21                                 KBA-EZ Health Guide            Medical
# 28                                            Ra Ga Ba             Arcade
# 47                                             Mu.F.O.             Arcade
# 82                                    Brick Breaker BR             Arcade
# 99     Anatomy & Physiology Vocabulary Exam Review App            Medical
# 114                                        FK Atlantas             Sports
# 126                                    Tablet Reminder            Medical
# 128                                            CQ ESPM           Business
# 141                                  Clinic Doctor EHr            Medical
# 151                                EB Cash Collections           Business
# 154                                            CZ-Help  Books & Reference
# 162                                          CB Heroes             Social
# ...

# %%
df_apps_clean[['App', 'Genres']].duplicated(['App', 'Genres']).any()
# Out:
# True

# %%
df_apps_clean[['App', 'Genres']][df_apps_clean[['App', 'Genres']].duplicated(['App', 'Genres'])]
# Out:
#                                              App   Genres
# 5510  Cardiac diagnosis (heart rate, arrhythmia)  Medical

# %%
df_apps_clean['Genres'].value_counts()
# Out:
# Tools                                718
# Entertainment                        467
# Education                            429
# Productivity                         301
# Personalization                      298
#                                     ...
# Travel & Local;Action & Adventure      1
# Casual;Music & Video                   1
# Health & Fitness;Education             1
# Role Playing;Brain Games               1
# Art & Design;Pretend Play              1
# Name: Genres, Length: 114, dtype: int64

# %%
# print(type(df_apps_clean['Genres'].loc[21]))
print(df_apps_clean['Genres'].str.split(';', expand=True).stack())
stack = df_apps_clean['Genres'].str.split(';', expand=True).stack()  # <--- learned something new
print(f'We now have a single column with shape: {stack.shape}')
num_genres = stack.value_counts()
print(f'Number of genres: {len(num_genres)}')
# df_apps_clean['Genres'] = df_apps_clean['Genres'].astype(str).str.split(';', "")
# # ---
# # Split the strings on the semi-colon and then .stack them.
# stack = df_apps_clean.Genres.str.split(';', expand=True).stack()
# print(f'We now have a single column with shape: {stack.shape}')
# num_genres = stack.value_counts()
# print(f'Number of genres: {len(num_genres)}')

# This shows us we actually have 53 different genres.
# Out:
# 21     0                    Medical
# 28     0                     Arcade
# 47     0                     Arcade
# 82     0                     Arcade
# 99     0                    Medical
#                      ...
# 10824  0               Productivity
# 10828  0    Video Players & Editors
# 10829  0    Video Players & Editors
# 10831  0           News & Magazines
# 10835  0                     Arcade
# Length: 8564, dtype: object
# We now have a single column with shape: (8564,)
# Number of genres: 53

# %%
# expand : bool, default False

# Expand the split strings into separate columns.
# -------
# If True, return DataFrame/MultiIndex expanding dimensionality.
# If False, return Series/Index, containing lists of strings.

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
# stack
print(stack.index[:15:])
print(num_genres.index[:15:])
print(num_genres.values[:15:])
# # print(num_genres.columns)
# print(num_genres)
bar = px.bar(
    x = num_genres.index[:15], # index = category name
    y = num_genres.values[:15], # count
    title='Top Genres', 
    hover_name=num_genres.index[:15], 
    color=num_genres.values[:15], 
    color_continuous_scale='Agsunset'
)
bar.update_layout(
    xaxis_title='Genre', 
    yaxis_title='Number of Apps',
)
bar.show()
# # ---
# # Solution: Working with Colour Scales in Plotly
# bar = px.bar(x = num_genres.index[:15], # index = category name
#              y = num_genres.values[:15], # count
#              title='Top Genres',
#              hover_name=num_genres.index[:15],
#              color=num_genres.values[:15],
#              color_continuous_scale='Agsunset')
 
# bar.update_layout(xaxis_title='Genre',
# yaxis_title='Number of Apps',
# coloraxis_showscale=False)
#
# bar.show()
# Out:
# MultiIndex([( 21, 0),
#             ( 28, 0),
#             ( 47, 0),
#             ( 82, 0),
#             ( 99, 0),
#             (114, 0),
#             (126, 0),
#             (128, 0),
#             (141, 0),
#             (151, 0),
#             (154, 0),
#             (162, 0),
#             (171, 0),
#             (174, 0),
#             (179, 0)],
#            )
# Index(['Tools', 'Education', 'Entertainment', 'Action', 'Productivity',
#        'Personalization', 'Lifestyle', 'Finance', 'Medical', 'Sports',
#        'Photography', 'Business', 'Communication', 'Health & Fitness',
#        'Casual'],
#       dtype='object')
# [719 587 498 304 301 298 298 296 292 270 263 262 258 245 216]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
# ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
# Now that we’ve looked at the total number of apps per category and the total 
# number of apps per genre, let’s see what the split is between free and paid 
# apps.
df_apps_clean['Type'].value_counts()
df_apps_clean.Type.value_counts()
# Out:
# Free    7595
# Paid     589
# Name: Type, dtype: int64

# %%
# We see that the majority of apps are free on the Google Play Store. But 
# perhaps some categories have more paid apps than others. Let’s investigate. We 
# can group our data first by Category and then by Type. Then we can add up the 
# number of apps per each type. Using as_index=False we push all the data into 
# columns rather than end up with our Categories as the index.
df_free_vs_paid = df_apps_clean.groupby(['Category', 'Type'], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid
# Out:
#              Category  Type  App
# 0      ART_AND_DESIGN  Free   58
# 1      ART_AND_DESIGN  Paid    3
# 2   AUTO_AND_VEHICLES  Free   72
# 3   AUTO_AND_VEHICLES  Paid    1
# 4              BEAUTY  Free   42
# ..                ...   ...  ...
# 56   TRAVEL_AND_LOCAL  Paid    8
# 57      VIDEO_PLAYERS  Free  144
# 58      VIDEO_PLAYERS  Paid    4
# 59            WEATHER  Free   65
# 60            WEATHER  Paid    7
#
# [61 rows x 3 columns]

# %%
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   58
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %%
df_free_vs_paid.tail()
# Out:
#             Category  Type  App
# 56  TRAVEL_AND_LOCAL  Paid    8
# 57     VIDEO_PLAYERS  Free  144
# 58     VIDEO_PLAYERS  Paid    4
# 59           WEATHER  Free   65
# 60           WEATHER  Paid    7

# %%
df_free_vs_paid.sort_values('App')
# Out:
#               Category  Type   App
# 3    AUTO_AND_VEHICLES  Paid     1
# 24      FOOD_AND_DRINK  Paid     2
# 38  NEWS_AND_MAGAZINES  Paid     2
# 40           PARENTING  Paid     2
# 17       ENTERTAINMENT  Paid     2
# ..                 ...   ...   ...
# 31           LIFESTYLE  Free   284
# 21             FINANCE  Free   289
# 53               TOOLS  Free   656
# 25                GAME  Free   834
# 19              FAMILY  Free  1456
#
# [61 rows x 3 columns]

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
# # The key is using the color and barmode parameters for the .bar() method. To 
# # get a particular order, you can pass a dictionary to the axis parameter in 
# # .update_layout().
# g_bar = px.bar(
#     df_free_vs_paid, 
#     x='Category', 
#     y='App', 
#     title='Free vs Paid Apps by Category', 
#     color='Type',  # <--- learned something new
#     barmode='group'
# )
 
# g_bar.update_layout(
#     xaxis_title='Category', 
#     yaxis_title='Number of Apps', 
#     xaxis={'categoryorder':'total descending'}, 
#     yaxis=dict(type='log')
# )
 
# g_bar.show()

# ---

fvp_bar_chart = px.bar(
    df_free_vs_paid,
    x=df_free_vs_paid['Category'], 
    y=df_free_vs_paid.App, 
    title='Free vs Paid Apps by Category', 
    # color='Type', 
    color=df_free_vs_paid['Type'],  # <--- learned something new
    # color=df_free_vs_paid.Type, 
    barmode='group', 
)

fvp_bar_chart.update_layout(
    xaxis_title='Category', 
    yaxis_title='Number of Apps', 
    xaxis={'categoryorder': 'total descending'}, 
    yaxis=dict(type='log')
)

fvp_bar_chart.show()

# What we see is that while there are very few paid apps on the Google Play 
# Store, some categories have relatively more paid apps than others, including 
# Personalization, Medical and Weather. So, depending on the category you are 
# targeting, it might make sense to release a paid-for app.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d36fc276-d68d-4f20-a61d-a3b7c837c9ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d36fc276-d68d-4f20-a61d-a3b7c837c9ee")) {
#                     Plotly.newPlot(
#                         'd36fc276-d68d-4f20-a61d-a3b7c837c9ee',
# ...

# %%
# But this leads to many more questions:

# How much should you charge? What are other apps charging in that category?
# How much revenue could you make?
# And how many downloads are you potentially giving up because your app is paid?

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
# # Let’s try and answer these questions with some Box plots. Box plots show us 
# # some handy descriptive statistics in a graph - things like the median value, 
# # the maximum value, the minimum value, and some quartiles.
# box = px.box(
#     df_apps_clean, 
#     y='Installs', 
#     x='Type', 
#     color='Type', 
#     notched=True, 
#     points='all', 
#     title='How Many Downloads are Paid Apps Giving Up?'
# )
 
# box.update_layout(yaxis=dict(type='log'))
 
# box.show()

# ---

box_and_whisker = px.box(
    df_apps_clean, 
    title='How Many Downloads are Paid Apps Giving Up?', 
    y=df_apps_clean['Installs'], 
    x=df_apps_clean.Type, 
    color='Type',  # <--- learned something new
    notched=True,  # <--- learned something new
    points='all',  # <--- learned something new
)
 
box_and_whisker.update_layout(yaxis=dict(type='log'))

box_and_whisker.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fe4e7caa-cca4-42bd-9e2a-a703137cbc29" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fe4e7caa-cca4-42bd-9e2a-a703137cbc29")) {
#                     Plotly.newPlot(
#                         'fe4e7caa-cca4-42bd-9e2a-a703137cbc29',
# ...

# %%
# From the hover text in the chart, we see that the median number of downloads 
# for free apps is 500,000, while the median number of downloads for paid apps 
# is around 5,000! This is massively lower.

# But does this mean we should give up on selling a paid app? Let’s see how much 
# revenue we would estimate per category.

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
# # So, if you were to list a paid app, how should you price it? To help you 
# # decide we can look at how your competitors in the same category price their 
# # apps.
# df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']

# box = px.box(
#     df_paid_apps, 
#     x='Category', 
#     y='Revenue_Estimate', 
#     title='How Much Can Paid Apps Earn?'
# )
 
# box.update_layout(
#     xaxis_title='Category', 
#     yaxis_title='Paid App Ballpark Revenue', 
#     xaxis={'categoryorder':'min ascending'}, 
#     # xaxis={'categoryorder':'max ascending'}, 
#     yaxis=dict(type='log')
# )
  
# box.show()

# ---

df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']  # c'mon! simple stuff! fuck.

box_and_whisker = px.box(
    # df_apps_clean, 
    df_paid_apps, 
    title='How Much Can Paid Apps Earn?', 
    # x=df_apps_clean['Category'], 
    # y=df_apps_clean.Revenue_Estimate, 
    x=df_paid_apps['Category'], 
    y=df_paid_apps.Revenue_Estimate, 
)

box_and_whisker.update_layout(
    xaxis_title='Category', 
    yaxis_title='Paid App Ballpark Revenue', 
    xaxis={'categoryorder':'min ascending'}, 
    # xaxis={'categoryorder':'max ascending'}, 
    yaxis=dict(type='log')
)

box_and_whisker.show()

# # # df_apps_clean
# # df_apps_clean['Revenue_Estimate']
# df_apps_clean[df_apps_clean['Type'] == 'Paid']
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="aee9b3b5-fad5-46bf-8555-178e38b2364b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aee9b3b5-fad5-46bf-8555-178e38b2364b")) {
#                     Plotly.newPlot(
#                         'aee9b3b5-fad5-46bf-8555-178e38b2364b',
# ...

# %%
# If an Android app costs $30,000 to develop, then the average app in very few 
# categories would cover that development cost. The median paid photography app 
# earned about $20,000. Many more app’s revenues were even lower - meaning they 
# would need other sources of revenue like advertising or in-app purchases to 
# make up for their development costs. However, certain app categories seem to 
# contain a large number of outliers that have much higher (estimated) revenue - 
# for example in Medical, Personalisation, Tools, Game, and Family.

# So, if you were to list a paid app, how should you price it? To help you 
# decide we can look at how your competitors in the same category price their 
# apps.

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
# What is the median price for a paid app?
df_paid_apps['Price'].median()  # <--- learned something new
# df_paid_apps.Price.median()

# The median price for an Android app is $2.99.
# Out:
# 2.99

# %%
# box = px.box(
#     df_paid_apps, 
#     x='Category', 
#     y="Price", 
#     title='Price per Category'
# )
 
# box.update_layout(
#     xaxis_title='Category', 
#     yaxis_title='Paid App Price', 
#     xaxis={'categoryorder':'max descending'}, 
#     yaxis=dict(type='log')
# )
 
# box.show()

# ---

box_and_whisker = px.box(
    # df_apps_clean, 
    df_paid_apps, 
    title='Price Per Category', 
    # x=df_apps_clean['Category'], 
    # y=df_apps_clean.Price, 
    x=df_paid_apps['Category'], 
    y=df_paid_apps.Price,
)

box_and_whisker.update_layout(
    xaxis_title='Category', 
    yaxis_title='Paid App Price', 
    xaxis={'categoryorder':'max descending'}, 
    # xaxis={'categoryorder':'min descending'}, 
    yaxis=dict(type='log')
)

box_and_whisker.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9ab9c7d2-409d-47e1-9dfd-6e21c03db265" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9ab9c7d2-409d-47e1-9dfd-6e21c03db265")) {
#                     Plotly.newPlot(
#                         '9ab9c7d2-409d-47e1-9dfd-6e21c03db265',
# ...

# %%
# However, some categories have higher median prices than others. This time we 
# see that Medical apps have the most expensive apps as well as a median price 
# of $5.49. In contrast, Personalisation apps are quite cheap on average at 
# $1.49. Other categories which higher median prices are Business ($4.99) and 
# Dating ($6.99). It seems like customers who shop in these categories are not 
# so concerned about paying a bit extra for their apps.

# %%
df_paid_apps
# Out:
#                                                     App  ... Revenue_Estimate
# 28                                             Ra Ga Ba  ...             1.49
# 47                                              Mu.F.O.  ...             0.99
# 233              Chess of Blades (BL/Yaoi Game) (No VA)  ...           149.90
# 248                                        The DG Buddy  ...            24.90
# 291                                 AC DC Power Monitor  ...            30.40
# ...                                                 ...  ...              ...
# 7957  League of Stickman 2018- Ninja Arena PVP(Dream...  ...       990,000.00
# 7977                            Sleep as Android Unlock  ...     5,990,000.00
# 7988                                  Where's My Water?  ...     1,990,000.00
# 8825                                      Hitman Sniper  ...     9,900,000.00
# 9220                                          Minecraft  ...    69,900,000.00
#
# [589 rows x 11 columns]
